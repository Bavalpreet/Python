# %%
#CREDITS = Think Python by o'reilly    link-https://greenteapress.com/thinkpython2/thinkpython2.pdf
#maths functions
import math
radians = 0.7
height = math.sin(radians)
print(height)
# Out:
# 0.644217687237691

# %%
math.sqrt(2) / 2.0 #using squareroot function
# Out:
# 0.7071067811865476

# %%
degrees = 45
radians = degrees / 180.0 * math.pi
print(math.sin(radians))
# Out:
# 0.7071067811865475

# %%
#One of the most useful features of programming languages is their ability to take small
#building blocks and compose them. For example, the argument of a function can be any
#kind of expression, including arithmetic operators:
x = math.sin(degrees / 360.0 * 2 * math.pi)
print(x)
# Out:
# 0.7071067811865475

# %%
def print_twice(bruce):# function defination
  print(bruce)         #function body
  print(bruce)
print_twice('baval')   #function all with parameter baval
# Out:
# baval
# baval

# %%
#Void functions might display something on the screen or have some other effect, but they
#don’t have a return value. If you assign the result to a variable, you get a special value
#called None
result = print_twice('bing')# see what function is written in function body is performed but has no return type
print(result)               #as it is having no return value you are getting special value called None
# Out:
# bing
# bing
# None

# %%
#The value None is not the same as the string 'None'. It is a special value that has its own
#type:
type(None)
# Out:
# NoneType
